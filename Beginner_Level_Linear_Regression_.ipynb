# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bos_df = pd.read_csv("/content/BostonHousing.csv")

# %%
print(bos_df.head())
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df = bos_df.dropna()

# Verify that there are no missing values
print(df.isnull().sum())
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
bos_df.shape
# Out:
# (506, 14)

# %%
bos_df.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  501.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284341
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.705587
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.884000
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208000
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.625000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             lstat        medv
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %%
bos_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   crim     506 non-null    float64
#  1   zn       506 non-null    float64
#  2   indus    506 non-null    float64
#  3   chas     506 non-null    int64
#  4   nox      506 non-null    float64
#  5   rm       501 non-null    float64
#  6   age      506 non-null    float64
#  7   dis      506 non-null    float64
#  8   rad      506 non-null    int64
#  9   tax      506 non-null    int64
#  10  ptratio  506 non-null    float64
#  11  b        506 non-null    float64
#  12  lstat    506 non-null    float64
#  13  medv     506 non-null    float64
# dtypes: float64(11), int64(3)
# memory usage: 55.5 KB

# %%
bos_df[bos_df.duplicated()==True]
# Out:
# Empty DataFrame
# Columns: [crim, zn, indus, chas, nox, rm, age, dis, rad, tax, ptratio, b, lstat, medv]
# Index: []

# %%
bos_df['medv'].head(10)
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# 5    28.7
# 6    22.9
# 7    27.1
# 8    16.5
# 9    18.9
# Name: medv, dtype: float64

# %%
bos_df['medv'].tail(10)
# Out:
# 496    19.7
# 497    18.3
# 498    21.2
# 499    17.5
# 500    16.8
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, dtype: float64

# %%
bos_df['medv'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %%
bos_df['medv'].isna().sum()
# Out:
# 0

# %%
corr=bos_df.corr()
corr.tail(1)
# Out:
#           crim        zn     indus     chas       nox        rm       age  \
# medv -0.388305  0.360445 -0.483725  0.17526 -0.427321  0.696169 -0.376955
#
#            dis       rad       tax   ptratio         b     lstat  medv
# medv  0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663   1.0

# %%
import matplotlib.pyplot as plt

def pllot(x, y, color='blue'):
    plt.scatter(bos_df[x], bos_df[y], color=color)
    plt.xlabel(x)
    plt.ylabel(y)
    plt.title("Scatter plot of " + x + " and " + y)
    plt.show()

x_names = bos_df.columns[0:13]
y_name = bos_df.columns[-1]

for i in x_names:
    pllot(i, y_name, color='red')  # Change 'red' to any color you want

# %%
sns.boxplot(x='medv',data=bos_df)
# Out:
# <Axes: xlabel='medv'>

# %%
bos_df['medv'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %%
print(np.where(bos_df['medv']>50))
# Out:
# (array([], dtype=int64),)

# %%
sns.scatterplot(bos_df['medv'])
plt.show()

# %%
from sklearn import preprocessing
scale = preprocessing.StandardScaler()

# %%
bos_df = scale.fit_transform(bos_df)

# %%
columns=['CRIM','ZN','INDUS','CHAS','NOX','RM','AGE','DIS','RAD','TAX','PTRATIO','B','LSTAT','MEDV']

# %%
df = pd.DataFrame(bos_df,columns=columns)

# %%
df
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.412351 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.193874  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.277743 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.012451 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.223834 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.437887  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.233147  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.981240  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.723041  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.360828  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0    0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562  0.159686
# 1    0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439 -0.101524
# 2    0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.208727  1.324247
# 3    1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.361517  1.182758
# 4    1.077737 -0.752922 -1.106115  0.113032  0.441052 -1.026501  1.487503
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.625796 -0.982843 -0.803212  1.176466  0.387217 -0.418147 -0.014454
# 502 -0.716639 -0.982843 -0.803212  1.176466  0.441052 -0.500850 -0.210362
# 503 -0.773684 -0.982843 -0.803212  1.176466  0.441052 -0.983048  0.148802
# 504 -0.668437 -0.982843 -0.803212  1.176466  0.403225 -0.865302 -0.057989
# 505 -0.613246 -0.982843 -0.803212  1.176466  0.441052 -0.669058 -1.157248
#
# [506 rows x 14 columns]

# %%
np.round(df['MEDV'],3)
# Out:
# 0      0.160
# 1     -0.102
# 2      1.324
# 3      1.183
# 4      1.488
#        ...
# 501   -0.014
# 502   -0.210
# 503    0.149
# 504   -0.058
# 505   -1.157
# Name: MEDV, Length: 506, dtype: float64

# %%
df['MEDV'].describe()
# Out:
# count    5.060000e+02
# mean    -5.195668e-16
# std      1.000990e+00
# min     -1.908226e+00
# 25%     -5.994557e-01
# 50%     -1.450593e-01
# 75%      2.685231e-01
# max      2.989460e+00
# Name: MEDV, dtype: float64

# %%
sns.boxplot(x=df['MEDV'])
# Out:
# <Axes: xlabel='MEDV'>

# %%
#find the limits
upper_limit = df['MEDV'].mean()+3*df['MEDV'].std()
lower_limit = df['MEDV'].mean()-3*df['MEDV'].std()

print("upper limit: ", upper_limit)
print("lower limit: ", lower_limit)
# Out:
# upper limit:  3.002968828039714
# lower limit:  -3.002968828039715

# %%
df.loc[(df['MEDV'] > upper_limit) | (df['MEDV'] < lower_limit)]
# Out:
# Empty DataFrame
# Columns: [CRIM, ZN, INDUS, CHAS, NOX, RM, AGE, DIS, RAD, TAX, PTRATIO, B, LSTAT, MEDV]
# Index: []

# %%
q1 = df['MEDV'].quantile(0.25)

q3 = df['MEDV'].quantile(0.75)

iqr = q3-q1

# %%
q1, q3, iqr
# Out:
# (-0.5994557469772863, 0.26852313623367563, 0.867978883210962)

# %%
upper_limit = q3 + (1.5*iqr)
lower_limit = q1 - (1.5*iqr)

lower_limit, upper_limit
# Out:
# (-1.9014240717937292, 1.5704914610501186)

# %%
sns.boxplot(x=df['MEDV'])
# Out:
# <Axes: xlabel='MEDV'>

# %%
df.loc[(df['MEDV'] > upper_limit) | (df['MEDV'] < lower_limit)]
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
#
# 280  0.427669 -0.523001 -1.141751 -1.643945  0.335904 -1.246574  2.488808
# 282  0.673530 -0.523001 -1.141751 -1.643945  0.223629 -1.351705  2.554110
# 283  0.993501 -0.982843 -1.248658 -2.245017  0.425921 -1.330679  2.989460
# 291  0.628275 -0.637962 -0.969512  0.344213  0.441052 -1.274609  1.607224
# 368 -1.170617  1.661245  1.530926  0.806576  0.206634 -1.316661  2.989460
# 369 -1.159113  1.661245  1.530926  0.806576  0.204551 -1.250780  2.989460
# 370 -1.232462  1.661245  1.530926  0.806576  0.387875 -1.358713  2.989460
# 371 -1.248292  1.661245  1.530926  0.806576  0.103898 -0.437772  2.989460
# 372 -1.267069  1.661245  1.530926  0.806576 -0.096421 -0.528885  2.989460
# 398 -1.095936  1.661245  1.530926  0.806576  0.441052  2.514288 -1.908226
# 405 -1.126455  1.661245  1.530926  0.806576  0.310247  1.447566 -1.908226

# %%
new_df = df.loc[(df['MEDV'] < upper_limit) & (df['MEDV'] > lower_limit)]
print('before removing outliers: ', len(df))
print('after removing outliers: ', len(new_df))
print('outliers: ', len(df)-len(new_df))
# Out:
# before removing outliers:  506
# after removing outliers:  466
# outliers:  40

# %%
sns.boxplot(x=new_df['MEDV'])
# Out:
# <Axes: xlabel='MEDV'>

# %%
new_df = df.copy()
new_df.loc[(new_df['MEDV']>upper_limit),'MEDV'] = upper_limit
new_df.loc[(new_df['MEDV']<lower_limit),'MEDV'] = lower_limit

# %%
sns.boxplot(x=new_df['MEDV'])
# Out:
# <Axes: xlabel='MEDV'>

# %%
sns.scatterplot(new_df['MEDV'])
# Out:
# <Axes: ylabel='MEDV'>

# %%
new_df
# Out:
#          CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# 0   -0.419782  0.284830 -1.287909 -0.272599 -0.144217  0.412351 -0.120013
# 1   -0.417339 -0.487722 -0.593381 -0.272599 -0.740262  0.193874  0.367166
# 2   -0.417342 -0.487722 -0.593381 -0.272599 -0.740262  1.277743 -0.265812
# 3   -0.416750 -0.487722 -1.306878 -0.272599 -0.835284  1.012451 -0.809889
# 4   -0.412482 -0.487722 -1.306878 -0.272599 -0.835284  1.223834 -0.511180
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.413229 -0.487722  0.115738 -0.272599  0.158124  0.437887  0.018673
# 502 -0.415249 -0.487722  0.115738 -0.272599  0.158124 -0.233147  0.288933
# 503 -0.413447 -0.487722  0.115738 -0.272599  0.158124  0.981240  0.797449
# 504 -0.407764 -0.487722  0.115738 -0.272599  0.158124  0.723041  0.736996
# 505 -0.415000 -0.487722  0.115738 -0.272599  0.158124 -0.360828  0.434732
#
#           DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# 0    0.140214 -0.982843 -0.666608 -1.459000  0.441052 -1.075562  0.159686
# 1    0.557160 -0.867883 -0.987329 -0.303094  0.441052 -0.492439 -0.101524
# 2    0.557160 -0.867883 -0.987329 -0.303094  0.396427 -1.208727  1.324247
# 3    1.077737 -0.752922 -1.106115  0.113032  0.416163 -1.361517  1.182758
# 4    1.077737 -0.752922 -1.106115  0.113032  0.441052 -1.026501  1.487503
# ..        ...       ...       ...       ...       ...       ...       ...
# 501 -0.625796 -0.982843 -0.803212  1.176466  0.387217 -0.418147 -0.014454
# 502 -0.716639 -0.982843 -0.803212  1.176466  0.441052 -0.500850 -0.210362
# 503 -0.773684 -0.982843 -0.803212  1.176466  0.441052 -0.983048  0.148802
# 504 -0.668437 -0.982843 -0.803212  1.176466  0.403225 -0.865302 -0.057989
# 505 -0.613246 -0.982843 -0.803212  1.176466  0.441052 -0.669058 -1.157248
#
# [506 rows x 14 columns]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     506 non-null    float64
#  1   ZN       506 non-null    float64
#  2   INDUS    506 non-null    float64
#  3   CHAS     506 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       501 non-null    float64
#  6   AGE      506 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    float64
#  9   TAX      506 non-null    float64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    506 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(14)
# memory usage: 55.5 KB

# %%
new_df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         5
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
new_df.dropna(inplace=True)

# %%
new_df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX  \
# count  501.000000  501.000000  501.000000  501.000000  501.000000
# mean     0.003944    0.001655    0.003478    0.002721    0.003939
# std      1.005196    1.004928    1.000518    1.005609    1.003656
# min     -0.419782   -0.487722   -1.557842   -0.272599   -1.465882
# 25%     -0.410976   -0.487722   -0.867691   -0.272599   -0.913029
# 50%     -0.390064   -0.487722   -0.211099   -0.272599   -0.144217
# 75%      0.009262    0.048772    1.015999   -0.272599    0.598679
# max      9.933931    3.804234    2.422565    3.668398    2.732346
#
#                  RM         AGE         DIS         RAD         TAX  \
# count  5.010000e+02  501.000000  501.000000  501.000000  501.000000
# mean  -1.843724e-16   -0.002188   -0.004098    0.005449    0.005384
# std    1.001000e+00    1.003243    0.999857    1.004237    1.003865
# min   -3.863541e+00   -2.335437   -1.267069   -0.982843   -1.313990
# 25%   -5.679549e-01   -0.838337   -0.811380   -0.637962   -0.767576
# 50%   -1.083036e-01    0.324494   -0.291089   -0.523001   -0.464673
# 75%    4.832845e-01    0.904131    0.628893    1.661245    1.530926
# max    3.540533e+00    1.117494    3.960518    1.661245    1.798194
#
#           PTRATIO           B       LSTAT        MEDV
# count  501.000000  501.000000  501.000000  501.000000
# mean    -0.000943   -0.004117   -0.001305   -0.068982
# std      1.001628    1.005125    1.004029    0.830466
# min     -2.707379   -3.907193   -1.531127   -1.901424
# 25%     -0.488039    0.203235   -0.803625   -0.602177
# 50%      0.251741    0.380090   -0.178450   -0.145059
# 75%      0.806576    0.433706    0.600916    0.268523
# max      1.638828    0.441052    3.548771    1.570491

# %%
X = new_df.drop("MEDV", axis=1)
y = new_df['MEDV']

# %%
X.shape
# Out:
# (501, 13)

# %%
y.shape
# Out:
# (501,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state= 21)

# %%
print("Shape of the train dataset features")
print(X_train.shape)
print("Shape of the test dataset features")
print(X_test.shape)
# Out:
# Shape of the train dataset features
# (400, 13)
# Shape of the test dataset features
# (101, 13)

# %%
print("Shape of train set target")
print(y_train.shape)
print("Shape of test set target")
print(y_test.shape)
# Out:
# Shape of train set target
# (400,)
# Shape of test set target
# (101,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model_linreg = LinearRegression()

# %%
model_linreg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print("The intercept for this Multiple Linear Regression model on the boston dataset is",
     model_linreg.intercept_)
# Out:
# The intercept for this Multiple Linear Regression model on the boston dataset is -0.07809160130882345

# %%
y_test_pred = model_linreg.predict(X_test)

# %%
print(y_test_pred)
# Out:
# [ 1.27959457  0.77148649 -0.69114906 -0.02801145  0.73057587 -0.06577848
#  -0.10358027 -0.33247338 -0.45602931  0.16845177  0.56628089  0.04726554
#  -0.57078687 -0.69785985  0.33101891 -0.82310005 -0.6868705  -0.72996611
#   0.1115286  -0.53864835  1.11168238  0.46176717  1.00672245  0.66050534
#   0.01393484  1.59686046 -0.66008565  0.24645311  0.48653371  0.97689347
#   0.23423302 -0.25192688  1.2184803  -0.67227351 -1.59448822  0.576459
#  -0.05527364 -0.49362612 -0.51243104 -0.57918921  0.14086622 -0.65579645
#   0.9265708  -0.97270134  0.34431329 -0.39276617  0.71165669  0.09607485
#  -0.0631141  -1.93120527  0.75753241 -0.40662555  0.70094185 -0.64169191
#   1.39640658  0.05768771  0.02534617 -1.80457283  0.06778254 -1.00337029
#  -0.47705639 -0.29892598  0.64475973  0.81447438  0.80014    -0.32461038
#   0.02653129 -0.70086377 -0.10958913 -1.66840823  0.81987742  0.24976688
#  -0.26126684  0.92062786  0.1409558   0.50198844 -0.48179957 -0.37089593
#  -0.49287108 -0.83755932 -0.61555006  0.15236907  0.06266151  0.54072232
#  -0.12101406  1.71029398 -1.62697372  0.21243436 -0.19889262 -0.29083806
#  -0.16796128 -0.25320956 -0.80038457  0.45896963 -0.05979466  0.73809197
#  -1.53001755 -0.1474628   0.469025    0.9916332  -2.09211316]

# %%
actual_vs_pred_df = pd.DataFrame({'Actual': y_test, 'Predicted' : y_test_pred})

# %%
actual_vs_pred_df.head(10)
# Out:
#        Actual  Predicted
# 162  1.570491   1.279595
# 175  0.747408   0.771486
# 449 -1.037527  -0.691149
# 349  0.442663  -0.028011
# 305  0.638571   0.730576
# 502 -0.210362  -0.065778
# 69  -0.177711  -0.103580
# 464 -0.123292  -0.332473
# 131 -0.319199  -0.456029
# 73   0.094383   0.168452

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Distribution of actual and predicted values
sns.histplot(data=actual_vs_pred_df, x="Actual", color="blue", alpha=0.5, label="Actual")
sns.histplot(data=actual_vs_pred_df, x="Predicted", color="red", alpha=0.5, label="Predicted")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.title("Distribution of Actual and Predicted Values")
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Calculate Mean Squared Error (MSE)
mse = mean_squared_error(y_test, y_test_pred)
print("Mean Squared Error (MSE):", mse)

# Calculate Root Mean Squared Error (RMSE)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)

# Calculate Mean Absolute Error (MAE)
mae = mean_absolute_error(y_test, y_test_pred)
print("Mean Absolute Error (MAE):", mae)
# Out:
# Mean Squared Error (MSE): 0.21563052248838718
# Root Mean Squared Error (RMSE): 0.464360336902698
# Mean Absolute Error (MAE): 0.3211254821865513

# %%
# Calculate Residual Plots
residuals = y_test - y_test_pred

# Plot Residuals vs. Predicted Values
plt.scatter(y_test_pred, residuals)
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()

# Plot Residuals vs. Actual Values
plt.scatter(y_test, residuals)
plt.xlabel("Actual Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
